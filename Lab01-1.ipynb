# %% [markdown]
# # Lab01-1: Say "Hello, World!" With Python
# https://www.hackerrank.com/challenges/py-hello-world

# %%
print("Hello, World")
# Out:
# Hello, World!

# %% [markdown]
# ## Are you ready? DIY at https://www.hackerrank.com/challenges/py-hello-world
